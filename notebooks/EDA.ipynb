# %%
import pandas as pd

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import numpy as np

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as pl

# %%
data=pd.read_csv(r'C:\Users\deyar\OneDrive\Desktop\Flight_Ticket_Price_Prediction\notebooks\data\flight.csv')

# %%
data.head(2)
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
#
#   arrival_time destination_city    class  duration  days_left  price
# 0        Night           Mumbai  Economy      2.17          1   5953
# 1      Morning           Mumbai  Economy      2.33          1   5953

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["airline"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                    explode=[0.01,.01,0.01,0.01,.01,0.2])
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="airline",color="r")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %% [markdown]
# vistara has highest market cap.
# spicejet has lowest market cap.
# according the data

# %%
pl.figure(figsize=(20,4))
a=sn.countplot(data=data,x="airline",hue="destination_city")
for i in a.containers:
  a.bar_label(i)

pl.figure(figsize=(20,4))
a=sn.countplot(data=data,x="airline",hue="source_city")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %% [markdown]
# 1.spicejet oparate max flights from delhi

# %% [markdown]
# 2.air asia oparate max flights from delhi

# %% [markdown]
# 3.vistara oparate max flights from mumbai  and bangalore

# %% [markdown]
# 4.go first air oparate max flights from delhi and mumbai

# %% [markdown]
# 5.indigo oparate max flights from delhi

# %% [markdown]
# 6.air india oparate max flights from mumbai

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["source_city"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                    explode=[0.01,.01,0.01,0.01,.01,0.2])
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="source_city",color="r")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %% [markdown]
# delhi and amumbai is having highest no of flights.

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["stops"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                  explode=[0,0.01,0.1])
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="stops",color="g")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %% [markdown]
# there are one stop flights most.

# %%
d1=data[data["source_city"]=="Delhi"]
v=sn.countplot(data=d1,x="destination_city",hue="source_city",palette='colorblind')
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max delhi flights have gone to mumbai

# %%
d2=data[data["source_city"]=="Chennai"]
v=sn.countplot(data=d2,x="destination_city",hue="source_city",palette='dark')
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max chennai flights have gone to delhi

# %%
d1=data[data["source_city"]=="Mumbai"]
v=sn.countplot(data=d1,x="destination_city",hue="source_city",palette='husl')
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max mumbai flights have gone to delhi

# %%
d1=data[data["source_city"]=="Hyderabad"]
v=sn.countplot(data=d1,x="destination_city",hue="source_city")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max hyderabad flights have gone to mumbai

# %%
d1=data[data["source_city"]=="Bangalore"]
v=sn.countplot(data=d1,x="destination_city",hue="source_city")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max bangalore flights has gone to delhi

# %%
d1=data[data["source_city"]=="Kolkata"]
v=sn.countplot(data=d1,x="destination_city",hue="source_city")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max kolkata flights have gone to mumbai

# %%
d1=data[data["stops"]=="zero"]
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
v=sn.countplot(data=d1,x="destination_city",hue="stops",palette='dark')
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
v=sn.countplot(data=d1,x="source_city",hue="stops")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# max zero stops flights came from delhi

# %%
d1=data[data["stops"]=="one"]
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
v=sn.countplot(data=d1,x="destination_city",hue="stops",palette='muted')
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
v=sn.countplot(data=d1,x="source_city",hue="stops",palette='rocket')
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# one stops flights came from mumbai

# %%
d1=data[data["stops"]=="two_or_more"]
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
v=sn.countplot(data=d1,x="destination_city",hue="stops",palette="husl")
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
v=sn.countplot(data=d1,x="source_city",hue="stops",palette='bright')
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# 2 or more than 2 stops flights came from kolkata and chennai

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
v=sn.countplot(data=data,x="departure_time",palette='dark')
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
c=sn.countplot(data=data,x="arrival_time",palette='dark')
for i in c.containers:
  c.bar_label(i)
pl.show()

# %% [markdown]
# max flights have taken off in morning but reached at destination at night.

# %%
pl.figure(figsize=(25,3))
pl.subplot(1,1,1)
v=sn.countplot(data=data,x="departure_time",hue="source_city")
for i in v.containers:
  v.bar_label(i)
pl.figure(figsize=(25,6))
pl.subplot(2,1,1)
c=sn.countplot(data=data,x="arrival_time",hue="destination_city")
for i in c.containers:
  c.bar_label(i)
pl.show()

# %% [markdown]
# 1.delhi flights have taken off at evening

# %% [markdown]
# 2.mumbai flights have taken off at early  morning

# %% [markdown]
# 3.delhi flights have taken off at morning

# %% [markdown]
# 4.delhi flights have taken off at afternoon

# %% [markdown]
# 5.bangalore flights have taken off at late night

# %% [markdown]
# 6.mumbai flights have taken off at night reached to mumbai at night

# %% [markdown]
# 7.max flights have reached kolkta at moring and evening

# %% [markdown]
# 8.max flights have reached hyderabad at early mornig

# %% [markdown]
# 9.max flights have reached delhi at late night

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
v=sn.countplot(data=data,x="class",color='g')
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
data["class"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                  explode=[0,0.1])
pl.show()

# %% [markdown]
# max ticket have been booked for economy class

# %%
v=sn.countplot(data=data,x="class",hue="airline")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# vistara and air india offer busness class ticket

# %%
pl.figure(figsize=(20,4))
pl.subplot(1,2,1)
v=sn.countplot(data=data,x="class",hue="source_city")
for i in v.containers:
  v.bar_label(i)
pl.subplot(1,2,2)
v=sn.countplot(data=data,x="class",hue="destination_city")
for i in v.containers:
  v.bar_label(i)
pl.show()

# %% [markdown]
# mumbai people booked busness class most and in economy class delhi is having max no

# %%
pl.figure(figsize=(20,6))
sn.kdeplot(data=data,x="price",hue="airline",palette='dark')
pl.show()

# %% [markdown]
# air india offers cheapes busness class

# %%
pl.figure(figsize=(20,6))
sn.kdeplot(data=data,x="duration",hue="source_city")
pl.show()

# %% [markdown]
# kolkata and bangalore fights are having high time duration

# %% [markdown]
# sns.scatterplot(x='duration', y='price', data = data)

# %%
pl.figure(figsize=(20,6))
sn.regplot(x='duration', y='price', data = data)
pl.figure(figsize=(20,6))
sn.regplot(x='duration', y='price', data = data,scatter=False,ci=None,order=2)
pl.show()

# %% [markdown]
# from 0-20 price is has increased but after 20 price has been decreased W.T.R of duration

# %%
pl.figure(figsize=(20,6))
sn.regplot(x='days_left', y='price', data = data)
pl.figure(figsize=(20,6))
sn.regplot(x='days_left', y='price', data = data,scatter=False,ci=None,order=2)
pl.show()

# %% [markdown]
# if you book flight immediet then price will be high the it is deccresing till 35 days,then suddenly increasing.

# %%
pl.figure(figsize=(20,6))
sn.kdeplot(data=data,x='price',hue="stops")
pl.show()

# %% [markdown]
# one stop flights are expensive most
